# %%
### Video to images

# %%
import cv2
import matplotlib.image as im
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import os
from AI.utils import BatchGenerator

# %%
def image_extractor():
    vidcap = cv2.VideoCapture('data/videos/cleaned_data/data4/data4_car.mp4')
    count = 2235
    c = 1
    success = True
    while success:     
        success,image = vidcap.read()
        if(c%3==0):
            c += 1
            continue
        cv2.imwrite(f"data_/car{count}.jpg", image)
        count += 1
        print(c)
        c += 1
        
def combine():
    df1 = pd.read_csv('data\speed_data1.csv',index_col=0)
    df2 = pd.read_csv('data\speed_data2.csv',index_col=0)
    df3 = pd.read_csv('data\speed_data3.csv',index_col=0)
    df4 = pd.read_csv('data\speed_data4.csv',index_col=0)
    
    result = df1.append(df2).append(df3).append(df4)
    result.to_csv('data.csv')

### Pyramyding down the image
def scale_images():
    index=1
    for i in data['env']:
        img = cv2.imread(i)
        scaled_down1 = cv2.pyrDown(img)
        scaled_down2 = cv2.pyrDown(scaled_down1)
        img = cv2.cvtColor(scaled_down2,cv2.COLOR_BGR2RGB)
        plt.imsave(f'images/car{index}.jpg',img)
        index +=1

# %%
data = pd.read_csv('data.csv',index_col=0)
data
# Out:
#           speed                 env
# idx
# 1     20.000000     images/car1.jpg
# 2     20.000000     images/car2.jpg
# 3     20.000000     images/car3.jpg
# 4     20.000000     images/car4.jpg
# 5     20.000000     images/car5.jpg
# ...         ...                 ...
# 3344  28.066738  images/car3344.jpg
# 3345  28.274163  images/car3345.jpg
# 3346  28.353240  images/car3346.jpg
# 3347  28.954575  images/car3347.jpg
# 3348  29.003744  images/car3348.jpg
#
# [3348 rows x 2 columns]

# %%
genB = BatchGenerator(inputs=data['env'].iloc[:20],outputs=data['speed'].iloc[:20])

# %%
for i,j in genB:
    for k in i:
        plt.imshow(k)
        plt.show()
